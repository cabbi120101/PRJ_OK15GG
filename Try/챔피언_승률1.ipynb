# %% [markdown]
# <a href="https://colab.research.google.com/github/cabbi120101/final_multi/blob/main/Try/%EC%B1%94%ED%94%BC%EC%96%B8_%EC%8A%B9%EB%A5%A01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ast
import json
import os
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
game_basic_info = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/동욱코드모음/마지막프로젝트/3주차/시도/match_data_version1_participant_game_basic_info.csv")
game_basic_info.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    participantId  teamId  ...  highestAchievedSeasonTier        gameId
# 0              1     100  ...                        NaN  4.247263e+09
# 1              2     100  ...                        NaN  4.247263e+09
# 2              3     100  ...                        NaN  4.247263e+09
# 3              4     100  ...                        NaN  4.247263e+09
# 4              5     100  ...                        NaN  4.247263e+09
#
# [5 rows x 7 columns]

# %%
game_basic_info = game_basic_info.drop(['highestAchievedSeasonTier'], axis=1)

# %%
champ_info = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/동욱코드모음/마지막프로젝트/3주차/시도/champ_addSk.csv")
champ_info.head()
# Out:
#    Unnamed: 0  ...                                             skillR
# 0           0  ...  {'id': 'AatroxR', 'name': 'World Ender', 'desc...
# 1           1  ...  {'id': 'AhriTumble', 'name': 'Spirit Rush', 'd...
# 2           2  ...  {'id': 'AkaliR', 'name': 'Perfect Execution', ...
# 3           3  ...  {'id': 'AkshanR', 'name': 'Comeuppance', 'desc...
# 4           4  ...  {'id': 'FerociousHowl', 'name': 'Unbreakable W...
#
# [5 rows x 47 columns]

# %%
data_stats = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/동욱코드모음/마지막프로젝트/3주차/시도/match_data_version1_participant_game_stats_info.csv")
data_stats.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          gameId  participantId  assists  ...  wardsKilled  wardsPlaced    win
# 0  4.247263e+09              1        3  ...          1.0          6.0  False
# 1  4.247263e+09              2       10  ...          1.0         17.0  False
# 2  4.247263e+09              3        2  ...          1.0          5.0  False
# 3  4.247263e+09              4        4  ...          3.0          5.0  False
# 4  4.247263e+09              5        3  ...          7.0          5.0  False
#
# [5 rows x 105 columns]

# %%
game_who_win = data_stats[['gameId','win']]

# %%
game_champ_win = pd.merge(game_basic_info, game_who_win, how="left", on = None)

# %%
game_champ_win
# Out:
#           participantId  teamId  championId  ...  spell2Id        gameId    win
# 0                     1     100           7  ...         4  4.247263e+09  False
# 1                     1     100           7  ...         4  4.247263e+09  False
# 2                     1     100           7  ...         4  4.247263e+09  False
# 3                     1     100           7  ...         4  4.247263e+09  False
# 4                     1     100           7  ...         4  4.247263e+09  False
# ...                 ...     ...         ...  ...       ...           ...    ...
# 10875663             10     200         518  ...        13  4.225861e+09  False
# 10875664             10     200         518  ...        13  4.225861e+09  False
# 10875665             10     200         518  ...        13  4.225861e+09  False
# 10875666             10     200         518  ...        13  4.225861e+09  False
# 10875667             10     200         518  ...        13  4.225861e+09  False
#
# ...

# %%
game_champ_win = game_champ_win.drop(columns = ['gameId','spell2Id','spell1Id'], axis=1)

# %% [markdown]
# ## 머신러닝

# %%
# pip install pycaret

# %%
# pip install catboost

# %%
# !pip install -U scikit-learn

# %%
from pycaret.classification import *
from pycaret.regression import *

# %%
reg = setup(data= game_champ_win,
            target= 'win',
            # numeric_imputation = 'mean',
            # normalize = True,
            # silent= True
            )
# Out:
#                                Description             Value
# 0                               session_id              1853
# 1                                   Target               win
# 2                            Original Data     (10875668, 4)
# 3                           Missing Values             False
# 4                         Numeric Features                 1
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set     (7612967, 12)
# 10                    Transformed Test Set     (3262701, 12)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
best_5 = compare_models(sort='MAE', n_select=5)
# Out:
# IntProgress(value=0, description='Processing: ', max=94)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:20:21
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .    Bayesian Ridge
#                               Model  MAE   MSE  RMSE   R2   RMSLE    MAPE  \
# lr                Linear Regression  0.5  0.25   0.5 -0.0  0.3515  0.4998
# lasso              Lasso Regression  0.5  0.25   0.5 -0.0  0.3515  0.4998
# ridge              Ridge Regression  0.5  0.25   0.5 -0.0  0.3515  0.4998
# en                      Elastic Net  0.5  0.25   0.5 -0.0  0.3515  0.4998
# lar          Least Angle Regression  0.5  0.25   0.5 -0.0  0.3515  0.4998
# llar   Lasso Least Angle Regression  0.5  0.25   0.5 -0.0  0.3515  0.4998
# omp     Orthogonal Matching Pursuit  0.5  0.25   0.5 -0.0  0.3515  0.4998
#
#        TT (Sec)
# lr        2.782
# lasso     1.684
# ridge     1.833
# en        2.125
# lar       1.832
# ...
